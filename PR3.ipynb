# %%
name=input("Enter Your Name - ")
marks=int(input("Enter Your Marks"))
if marks>80:
    print("You have got an A Pass")
elif marks>=60:
    print("You have got a B Pass")
elif marks>=40:
    print("You have got a C Pass")
else:
    print("Sorry! you are fail")
# Out:
# Enter Your Name -  59
# Enter Your Marks 59
# You have got a C Pass
