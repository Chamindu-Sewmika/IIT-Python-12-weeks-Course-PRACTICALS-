# %%
first_name = input("Enter your first Name - ")
second_name = input("Enter your second Name - ")

subject1=int(input("Enter the subject 1 Marks - "))
subject2=int(input("Enter the subject 2 Marks - "))
subject3=int(input("Enter the subject 3 Marks - "))
subject4=int(input("Enter the subject 5 Marks - "))

total=subject1+subject2+subject3+subject4
average=total/4

print (first_name)
print(second_name)

print(subject1)
print(subject2)
print(subject3)
print(subject4)

print(total)
print(average)
# Out:
# Enter your first Name -  Chamindu
# Enter your second Name -  Wijesinghe
# Enter the subject 1 Marks -  70
# Enter the subject 2 Marks -  50
# Enter the subject 3 Marks -  50
# Enter the subject 5 Marks -  80
# Chamindu
# Wijesinghe
# 70
# 50
# 50
# 80
# 250
# 62.5
