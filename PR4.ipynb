# %% [markdown]
# ## Functions Questions

# %%
## Question 1

# %%
def func():
    print("Hello World !")

# %%
func()
# Out:
# Hello World !

# %%
## Question 2

# %%
def urname(name="User"):
    print(f"Hello {name} !")

# %%
urname("Chamindu")
# Out:
# Hello Chamindu !

# %%
## Question 3

# %%
def cal(a,b):
    return a+b

# %%
result=cal(2,3)
print (result)
# Out:
# 5

# %%
## Question 4

# %%
def count(number):
    if number%2==0:
        print("Even")
    else:
        print("Odd")

# %%
count(3)
# Out:
# Odd

# %%
count(4)
# Out:
# Even

# %%
def square(a):
    return(a*a)

# %%
square(6)
# Out:
# 36
